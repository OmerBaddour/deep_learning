# %%
from src.deep_learning.neuron import Neuron
from src.deep_learning.value import Value
from src.deep_learning.value import draw
from src.deep_learning.op import TANH

neuron = Neuron(
    weights=[1.0, 2.0, 3.0],
    bias=5.0,
)
value = neuron.forward(
    inputs=[1.0, 2.0, 3.0],
)
assert value.data == TANH.forward([1.0 ** 2 + 2.0 ** 2 + 3.0 ** 2 + 5.0])

value.gradient = 1.0
value.backward()
draw(value)
# Out:
# 4600624912: Value({'data': 1.0, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 1.0})
# 4600239584: Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600082032: Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})
# 4600625056: Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600624384: Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})
# 4600240400: Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0})
# 4600624960: Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600240736: Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})
# 4600085728: Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0})
# 4600624864: Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600239680: Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})
# 4600086352: Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0})
# ------------------------------
# 4600624912: Value({'data': 1.0, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 1.0})
# 4600624912: Value({'data': 1.0, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 1.0})
# 4600239584: Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600239584: Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600239584: Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600239584: Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600239584: Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600239584: Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600239584: Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600239584: Value({'data': 19.0, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 5.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600625056: Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600625056: Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600625056: Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600625056: Value({'data': 9.0, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 3.0, 'label': 'w2', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600624960: Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600624960: Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600624960: Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600624960: Value({'data': 4.0, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 2.0, 'label': 'w1', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 2.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600624864: Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600624864: Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600624864: Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# 4600624864: Value({'data': 1.0, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.0, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
