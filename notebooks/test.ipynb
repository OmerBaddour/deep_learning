# %%
from src.deep_learning.value import Value
from src.deep_learning.value import Op
from src.deep_learning.value import draw

def simple_value_graph() -> Value:
  a = Value(2, label='a')
  b = Value(3, label='b')
  c = Value(label='c', children=[a, b], op=Op.PLUS)

  d = Value(5, label='d')
  e = Value(6, label='e')
  f = Value(label='f', children=[d, e], op=Op.MULTIPLY)

  L = Value(label='L', children=[c, f], op=Op.PLUS)
  return L

def test_backward(simple_value_graph: Value):
  simple_value_graph.gradient = 1.0
  simple_value_graph.backward()
  
  L = simple_value_graph
  
  f = simple_value_graph.children[1]
  e = f.children[1]
  d = f.children[0]
  
  c = simple_value_graph.children[0]
  b = c.children[1]
  a = c.children[0]

  assert L.gradient == 1.0
  
  assert c.gradient == 1.0
  assert f.gradient == 1.0
  
  assert a.gradient == 1.0
  assert b.gradient == 1.0

  assert d.gradient == e.data
  assert e.gradient == d.data

test_backward(simple_value_graph())
# Out:
# Value({'data': 0.0, 'label': 'L', 'op': <Op.PLUS: '+'>, 'children': [Value({'data': 0.0, 'label': 'c', 'op': <Op.PLUS: '+'>, 'children': [Value({'data': 2.0, 'label': 'a', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.0, 'label': 'f', 'op': <Op.MULTIPLY: '*'>, 'children': [Value({'data': 5.0, 'label': 'd', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 6.0, 'label': 'e', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 1.0})
# Value({'data': 0.0, 'label': 'f', 'op': <Op.MULTIPLY: '*'>, 'children': [Value({'data': 5.0, 'label': 'd', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 6.0, 'label': 'e', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})
# Value({'data': 6.0, 'label': 'e', 'op': None, 'children': [], 'gradient': 0.0})
# ...
