# %%
from src.deep_learning.op import MULTIPLY
from src.deep_learning.op import PLUS
from src.deep_learning.value import Value
from src.deep_learning.value import draw

a = Value(2, label='a')
b = Value(3, label='b')
c = Value(label='c', children=[a, b], op=PLUS)

d = Value(5, label='d')
e = Value(6, label='e')
f = Value(label='f', children=[d, e], op=MULTIPLY)

L = Value(label='L', children=[c, f], op=PLUS)

# %%
draw(L)

# %%
L.forward()
# Out:
# Value({'data': 35.0, 'label': 'L', 'op': +, 'children': [Value({'data': 5.0, 'label': 'c', 'op': +, 'children': [Value({'data': 2.0, 'label': 'a', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 3.0, 'label': 'b', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 30.0, 'label': 'f', 'op': *, 'children': [Value({'data': 5.0, 'label': 'd', 'op': None, 'children': [], 'gradient': 0.0}), Value({'data': 6.0, 'label': 'e', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 0.0})

# %%
draw(L)

# %%
L.gradient = 1.0
L.backward()

# %%
draw(L)

# %%
from src.deep_learning.neuron import Neuron
from src.deep_learning.value import Value
from src.deep_learning.value import draw
from src.deep_learning.op import TANH

neuron = Neuron(
    weights=[1.0, 2.0, 3.0],
    bias=5.0,
)
value = neuron.build_graph(
    inputs=[1.0, 2.0, 3.0],
)
assert value.data == TANH.forward([1.0 ** 2 + 2.0 ** 2 + 3.0 ** 2 + 5.0])

value.gradient = 1.0
value.backward()
draw(value)

# %%
from src.deep_learning.op import PLUS
from src.deep_learning.layer import get_random_layer

layer = get_random_layer(3, 2)
inputs = [0.5, -0.5]
outputs = layer.build_graph(inputs)

loss = Value(
    data=PLUS.forward([output.data for output in outputs]),
    label='loss',
    op=PLUS,
    children=outputs,
)

draw(loss)

# %%
from src.deep_learning.multi_layer_perceptron import MultiLayerPerceptron

class Data:
  def __init__(self, inputs: list[float], outputs: list[float]):
    self.inputs = inputs
    self.outputs = outputs

data = [
    Data([2.0, 3.0, -1.0,], [1.0]),
    Data([3.0, -1.0, 0.5], [-1.0]),
    Data([0.5, 1.0, 1.0], [-1.0]),
    Data([1.0, 1.0, -1.0], [1.0]),
]

multi_layer_perceptron = MultiLayerPerceptron(
    layers=[
        get_random_layer(4, 3),
        get_random_layer(4, 4),
        get_random_layer(1, 4),
    ],
)

# %%
losses: list[float] = []

# %%
for i in range(10000):
  # compute loss
  predicted_outputs = [multi_layer_perceptron.build_graph(d.inputs) for d in data]
  sum_squared_difference_value = Value(0.0)
  for output, predicted_output in zip([d.outputs for d in data], predicted_outputs):
    output_value = Value(output[0])
    predicted_output_value = predicted_output[0]
    difference_value = output_value + (predicted_output_value * -1)
    squared_difference_value = difference_value ** 2
    sum_squared_difference_value += squared_difference_value
  loss = sum_squared_difference_value * (1 / len(predicted_outputs))
  loss.label = 'loss'

  losses.append(loss.data)

  loss.gradient = 1.0

  # zero gradients of parameters
  for layer in multi_layer_perceptron.layers:
    for neuron in layer.neurons:
      for weight_value in neuron.weight_values:
        weight_value.gradient = 0
      neuron.bias_value.gradient = 0

  loss.backward()

  # update parameters
  alpha = 0.01
  for layer in multi_layer_perceptron.layers:
    for neuron in layer.neurons:
      for weight_value in neuron.weight_values:
        weight_value.data = weight_value.data - weight_value.gradient * alpha
      neuron.bias_value.data = neuron.bias_value.data - neuron.bias_value.gradient * alpha

# %%
import matplotlib.pyplot as plt

plt.plot(losses)

# %%
[multi_layer_perceptron.build_graph(d.inputs) for d in data]
# Out:
# [[Value({'data': 0.9879924626904873, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 2.554673017035038, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.4261248322230458, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.620866014920273, 'label': 'w0', 'op': None, 'children': [], 'gradient': -0.0006849051255859778}), Value({'data': 0.8798536209010428, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 1.3751191831730822, 'label': 'sum', 'op': +, 'children': [Value({'data': 0.41112206020005954, 'label': 'w0x0', 'op': *, 'children': [Value({'data': -0.415221391139532, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.00014817583774372802}), Value({'data': -0.9901273609044509, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': -2.6530933564267847, 'label': 'sum', 'op': +, 'children': [Value({'data': -0.5287812290479227, 'label': 'w0x0', 'op': *, 'children': [Value({'data': -0.26439061452396134, 'label': 'w0', 'op': None, 'children': [], 'gradient': -0.0001242745140849676}), Value({'data': 2.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -1.8240732427708504, 'label': 'w1x1', 'op': *, 'children': [Value({'data': -0.6080244142569501, 'label': 'w1', 'op': None, 'children': [], 'gradient': -6.833091164748701e-05}), Value({'data': 3.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.47319114930571, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 0.47319114930571, 'label': 'w2', 'op': None, 'children': [], 'gradient': -0.00018165855493366777}), Value({'data': -1.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.1729522646976984, 'label': 'b', 'op': None, 'children': [], 'gradient': -0.00013099217343120155})], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.12966533934513735, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 0.13043912442339523, 'label': 'w1', 'op': None, 'children': [], 'gradient': -1.4000224558275615e-05}), Value({'data': 0.9940678451984527, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 2.908772227334158, 'label': 'sum', 'op': +, 'children': [Value({'data': 2.797675237034594, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.398837618517297, 'label': 'w0', 'op': None, 'children': [], 'gradient': 4.65506467848075e-06}), Value({'data': 2.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.22488445961885567, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 0.07496148653961855, 'label': 'w1', 'op': None, 'children': [], 'gradient': 2.234858798433796e-05}), Value({'data': 3.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.07666420540651084, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 0.07666420540651084, 'label': 'w2', 'op': None, 'children': [], 'gradient': 4.9470157269548925e-05}), Value({'data': -1.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.03712326391278068, 'label': 'b', 'op': None, 'children': [], 'gradient': 2.3101768691114025e-05})], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.14389411788297363, 'label': 'w2x2', 'op': *, 'children': [Value({'data': -0.14621497107935788, 'label': 'w2', 'op': None, 'children': [], 'gradient': 3.5556571265662307e-06}), Value({'data': 0.9841271165377133, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 2.4141610729740206, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.890924120593012, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 0.945462060296506, 'label': 'w0', 'op': None, 'children': [], 'gradient': 6.458797182343227e-06}), Value({'data': 2.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.6332574004376108, 'label': 'w1x1', 'op': *, 'children': [Value({' ...
#  [Value({'data': -0.9898521332255183, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': -2.639276048324404, 'label': 'sum', 'op': +, 'children': [Value({'data': -1.4366587136701978, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.620866014920273, 'label': 'w0', 'op': None, 'children': [], 'gradient': -0.0006849051255859778}), Value({'data': -0.8863525426812432, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': -1.4046495973584199, 'label': 'sum', 'op': +, 'children': [Value({'data': -0.0916427495446635, 'label': 'w0x0', 'op': *, 'children': [Value({'data': -0.415221391139532, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.00014817583774372802}), Value({'data': 0.22070816075530092, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 0.2244004100356195, 'label': 'sum', 'op': +, 'children': [Value({'data': -0.793171843571884, 'label': 'w0x0', 'op': *, 'children': [Value({'data': -0.26439061452396134, 'label': 'w0', 'op': None, 'children': [], 'gradient': -0.0001242745140849676}), Value({'data': 3.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.6080244142569501, 'label': 'w1x1', 'op': *, 'children': [Value({'data': -0.6080244142569501, 'label': 'w1', 'op': None, 'children': [], 'gradient': -6.833091164748701e-05}), Value({'data': -1.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.236595574652855, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 0.47319114930571, 'label': 'w2', 'op': None, 'children': [], 'gradient': -0.00018165855493366777}), Value({'data': 0.5, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.1729522646976984, 'label': 'b', 'op': None, 'children': [], 'gradient': -0.00013099217343120155})], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.13037067971208063, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 0.13043912442339523, 'label': 'w1', 'op': None, 'children': [], 'gradient': -1.4000224558275615e-05}), Value({'data': 0.9994752746799156, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 4.122760207802747, 'label': 'sum', 'op': +, 'children': [Value({'data': 4.196512855551891, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.398837618517297, 'label': 'w0', 'op': None, 'children': [], 'gradient': 4.65506467848075e-06}), Value({'data': 3.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.07496148653961855, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 0.07496148653961855, 'label': 'w1', 'op': None, 'children': [], 'gradient': 2.234858798433796e-05}), Value({'data': -1.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.03833210270325542, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 0.07666420540651084, 'label': 'w2', 'op': None, 'children': [], 'gradient': 4.9470157269548925e-05}), Value({'data': 0.5, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.03712326391278068, 'label': 'b', 'op': None, 'children': [], 'gradient': 2.3101768691114025e-05})], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.14499893692995194, 'label': 'w2x2', 'op': *, 'children': [Value({'data': -0.14621497107935788, 'label': 'w2', 'op': None, 'children': [], 'gradient': 3.5556571265662307e-06}), Value({'data': 0.9916832446060128, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 2.7392316048301506, 'label': 'sum', 'op': +, 'children': [Value({'data': 2.836386180889518, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 0.945462060296506, 'label': 'w0', 'op': None, 'children': [], 'gradient': 6.458797182343227e-06}), Value({'data': 3.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.21108580014587028, 'label': 'w1x1', 'op': *, 'children': [Valu ...
#  [Value({'data': -0.9823813518607247, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': -2.3615481047495885, 'label': 'sum', 'op': +, 'children': [Value({'data': -1.3188524978402443, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.620866014920273, 'label': 'w0', 'op': None, 'children': [], 'gradient': -0.0006849051255859778}), Value({'data': -0.8136715099829618, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': -1.1377986684367987, 'label': 'sum', 'op': +, 'children': [Value({'data': 0.038947662846041425, 'label': 'w0x0', 'op': *, 'children': [Value({'data': -0.415221391139532, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.00014817583774372802}), Value({'data': -0.09379975039136015, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': -0.09407630751552237, 'label': 'sum', 'op': +, 'children': [Value({'data': -0.13219530726198067, 'label': 'w0x0', 'op': *, 'children': [Value({'data': -0.26439061452396134, 'label': 'w0', 'op': None, 'children': [], 'gradient': -0.0001242745140849676}), Value({'data': 0.5, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.6080244142569501, 'label': 'w1x1', 'op': *, 'children': [Value({'data': -0.6080244142569501, 'label': 'w1', 'op': None, 'children': [], 'gradient': -6.833091164748701e-05}), Value({'data': 1.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.47319114930571, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 0.47319114930571, 'label': 'w2', 'op': None, 'children': [], 'gradient': -0.00018165855493366777}), Value({'data': 1.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.1729522646976984, 'label': 'b', 'op': None, 'children': [], 'gradient': -0.00013099217343120155})], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.08762218573922483, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 0.13043912442339523, 'label': 'w1', 'op': None, 'children': [], 'gradient': -1.4000224558275615e-05}), Value({'data': 0.6717477300354305, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 0.8139212372919973, 'label': 'sum', 'op': +, 'children': [Value({'data': 0.6994188092586485, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.398837618517297, 'label': 'w0', 'op': None, 'children': [], 'gradient': 4.65506467848075e-06}), Value({'data': 0.5, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.07496148653961855, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 0.07496148653961855, 'label': 'w1', 'op': None, 'children': [], 'gradient': 2.234858798433796e-05}), Value({'data': 1.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.07666420540651084, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 0.07666420540651084, 'label': 'w2', 'op': None, 'children': [], 'gradient': 4.9470157269548925e-05}), Value({'data': 1.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.03712326391278068, 'label': 'b', 'op': None, 'children': [], 'gradient': 2.3101768691114025e-05})], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.10272928690966113, 'label': 'w2x2', 'op': *, 'children': [Value({'data': -0.14621497107935788, 'label': 'w2', 'op': None, 'children': [], 'gradient': 3.5556571265662307e-06}), Value({'data': 0.7025907549091195, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 0.8723986117616609, 'label': 'sum', 'op': +, 'children': [Value({'data': 0.472731030148253, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 0.945462060296506, 'label': 'w0', 'op': None, 'children': [], 'gradient': 6.458797182343227e-06}), Value({'data': 0.5, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.21108580014587028, 'label': 'w1x1', 'op': *, 'children':  ...
#  [Value({'data': 0.9838101444111034, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 2.4041948710233245, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.3565223484407278, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.620866014920273, 'label': 'w0', 'op': None, 'children': [], 'gradient': -0.0006849051255859778}), Value({'data': 0.8369120803038445, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 1.2107758917813405, 'label': 'sum', 'op': +, 'children': [Value({'data': 0.3426079271028782, 'label': 'w0x0', 'op': *, 'children': [Value({'data': -0.415221391139532, 'label': 'w0', 'op': None, 'children': [], 'gradient': 0.00014817583774372802}), Value({'data': -0.825121090612953, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': -1.172653913388923, 'label': 'sum', 'op': +, 'children': [Value({'data': -0.26439061452396134, 'label': 'w0x0', 'op': *, 'children': [Value({'data': -0.26439061452396134, 'label': 'w0', 'op': None, 'children': [], 'gradient': -0.0001242745140849676}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.6080244142569501, 'label': 'w1x1', 'op': *, 'children': [Value({'data': -0.6080244142569501, 'label': 'w1', 'op': None, 'children': [], 'gradient': -6.833091164748701e-05}), Value({'data': 1.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.47319114930571, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 0.47319114930571, 'label': 'w2', 'op': None, 'children': [], 'gradient': -0.00018165855493366777}), Value({'data': -1.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.1729522646976984, 'label': 'b', 'op': None, 'children': [], 'gradient': -0.00013099217343120155})], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.11431629638919429, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 0.13043912442339523, 'label': 'w1', 'op': None, 'children': [], 'gradient': -1.4000224558275615e-05}), Value({'data': 0.8763957661823343, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 1.3600116357376242, 'label': 'sum', 'op': +, 'children': [Value({'data': 1.398837618517297, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 1.398837618517297, 'label': 'w0', 'op': None, 'children': [], 'gradient': 4.65506467848075e-06}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.07496148653961855, 'label': 'w1x1', 'op': *, 'children': [Value({'data': 0.07496148653961855, 'label': 'w1', 'op': None, 'children': [], 'gradient': 2.234858798433796e-05}), Value({'data': 1.0, 'label': 'x1', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.07666420540651084, 'label': 'w2x2', 'op': *, 'children': [Value({'data': 0.07666420540651084, 'label': 'w2', 'op': None, 'children': [], 'gradient': 4.9470157269548925e-05}), Value({'data': -1.0, 'label': 'x2', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.03712326391278068, 'label': 'b', 'op': None, 'children': [], 'gradient': 2.3101768691114025e-05})], 'gradient': 0.0})], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': -0.11411385715770578, 'label': 'w2x2', 'op': *, 'children': [Value({'data': -0.14621497107935788, 'label': 'w2', 'op': None, 'children': [], 'gradient': 3.5556571265662307e-06}), Value({'data': 0.7804526192859602, 'label': 'tanh', 'op': tanh, 'children': [Value({'data': 1.0465274123857742, 'label': 'sum', 'op': +, 'children': [Value({'data': 0.945462060296506, 'label': 'w0x0', 'op': *, 'children': [Value({'data': 0.945462060296506, 'label': 'w0', 'op': None, 'children': [], 'gradient': 6.458797182343227e-06}), Value({'data': 1.0, 'label': 'x0', 'op': None, 'children': [], 'gradient': 0.0})], 'gradient': 0.0}), Value({'data': 0.21108580014587028, 'label': 'w1x1', 'op': *, 'children': [Value({ ...
